# %%
# print misclassified model rows from dataset

import pandas as pd
from IPython.display import display

df = pd.read_excel("updated_output.xlsx")

cols = ['Products ID', 'Name', 'Castrads SKU', 'Family', 'Manufacturer', 'Tags',
       'Section Length (mm)', 'Leg Section Depth (mm)',
       'Mid Section Depth (mm)', 'Leg Section Height (mm)',
       'Mid Section Height (mm)', 'Leg Section Weight (kg)',
       'Mid Section Weight (kg)', 'Internal Volume (L)', 'Nipple Size Top (")',
       'Nipple Size Bottom (")', 'Pipe Centre Top To Floor (mm)',
       'Pipe Centre Bottom To Floor (mm)', 'Inter Axis Distance (mm)',
       'Exponent N', 'Factor Km', 'Output Dt50 (W)', 'Cross-brace type',
       'Top shape', 'Link to google drive image', 'DOP No.', 'Comments']

pd.set_option("display.max_colwidth", None) 
pd.set_option("display.max_columns", None)


display(df[df["Products ID"] == 11489][cols])


display(df[df["Products ID"] == 1207][cols])
# Out:
#      Products ID                                                Name  \
# 113        11489  American Radiator Company Perfection 2 Column 23in
#
#         Castrads SKU      Family               Manufacturer  \
# 113  ORC-ARC-PF-2C23  Perfection  American Radiator Company
#
#                                                  Tags  Section Length (mm)  \
# 113  ARC, National,Ornate Radiators, Ribbon, 2 Column                   64
#
#      Leg Section Depth (mm)  Mid Section Depth (mm)  Leg Section Height (mm)  \
# 113                     235                     184                      584
#
#      Mid Section Height (mm)  Leg Section Weight (kg)  \
# 113                      533                      7.5
#
#      Mid Section Weight (kg)  Internal Volume (L)  Nipple Size Top (")  \
# 113                      6.8                  1.9                  2.0
#
#      Nipple Size Bottom (")  Pipe Centre Top To Floor (mm)  \
# 113                     2.0                          535.0
#
# ...

# %% [markdown]
# Observable difference: "Leg section depth" and "mid section depth" threshold difference

# %%
display(df[df["Products ID"] == 10658][cols])
display(df[df["Products ID"] == 1042][cols])
# Out:
#      Products ID                                  Name Castrads SKU   Family  \
# 207        10658  Beeston Duchess Scroll 1 Column 24in   ORC-B-DS24  Duchess
#
#     Manufacturer                                          Tags  \
# 207      Beeston  Duchess, School, Ideal Plain, School, Scroll
#
#      Section Length (mm)  Leg Section Depth (mm)  Mid Section Depth (mm)  \
# 207                   76                     143                     121
#
#      Leg Section Height (mm)  Mid Section Height (mm)  \
# 207                      610                      559
#
#      Leg Section Weight (kg)  Mid Section Weight (kg)  Internal Volume (L)  \
# 207                      6.5                      6.1                  1.0
#
#      Nipple Size Top (")  Nipple Size Bottom (")  \
# 207                  2.0                     2.0
#
#      Pipe Centre Top To Floor (mm)  Pipe Centre Bottom To Floor (mm)  \
# 207                          565.0                               102
#
# ...

# %% [markdown]
# Observable difference: different product id

# %%
display(df[df["Products ID"] == 10661][cols])
display(df[df["Products ID"] == 1045][cols])
# Out:
#      Products ID                                  Name Castrads SKU   Family  \
# 208        10661  Beeston Duchess Scroll 1 Column 30in   ORC-B-DS30  Duchess
#
#     Manufacturer                                          Tags  \
# 208      Beeston  Duchess, School, Ideal Plain, School, Scroll
#
#      Section Length (mm)  Leg Section Depth (mm)  Mid Section Depth (mm)  \
# 208                   76                     143                     121
#
#      Leg Section Height (mm)  Mid Section Height (mm)  \
# 208                      762                      711
#
#      Leg Section Weight (kg)  Mid Section Weight (kg)  Internal Volume (L)  \
# 208                      8.0                      7.2                  1.2
#
#      Nipple Size Top (")  Nipple Size Bottom (")  \
# 208                  2.0                     2.0
#
#      Pipe Centre Top To Floor (mm)  Pipe Centre Bottom To Floor (mm)  \
# 208                          718.0                               102
#
# ...

# %% [markdown]
# Observable difference: different product id

# %%
display(df[df["Products ID"] == 10664][cols])
display(df[df["Products ID"] == 1048][cols])
# Out:
#      Products ID                                  Name Castrads SKU   Family  \
# 209        10664  Beeston Duchess Scroll 1 Column 36in   ORC-B-DS36  Duchess
#
#     Manufacturer                                          Tags  \
# 209      Beeston  Duchess, School, Ideal Plain, School, Scroll
#
#      Section Length (mm)  Leg Section Depth (mm)  Mid Section Depth (mm)  \
# 209                   76                     143                     121
#
#      Leg Section Height (mm)  Mid Section Height (mm)  \
# 209                      914                      864
#
#      Leg Section Weight (kg)  Mid Section Weight (kg)  Internal Volume (L)  \
# 209                      8.6                      7.7                  1.4
#
#      Nipple Size Top (")  Nipple Size Bottom (")  \
# 209                  2.0                     2.0
#
#      Pipe Centre Top To Floor (mm)  Pipe Centre Bottom To Floor (mm)  \
# 209                          870.0                               102
#
# ...

# %% [markdown]
# Observable difference: different product id

# %%
display(df[df["Products ID"] == 10667][cols])
display(df[df["Products ID"] == 1051][cols])
# Out:
#      Products ID                                  Name Castrads SKU   Family  \
# 210        10667  Beeston Duchess Scroll 1 Column 39in   ORC-B-DS39  Duchess
#
#     Manufacturer                                          Tags  \
# 210      Beeston  Duchess, School, Ideal Plain, School, Scroll
#
#      Section Length (mm)  Leg Section Depth (mm)  Mid Section Depth (mm)  \
# 210                   76                     143                     140
#
#      Leg Section Height (mm)  Mid Section Height (mm)  \
# 210                      991                      933
#
#      Leg Section Weight (kg)  Mid Section Weight (kg)  Internal Volume (L)  \
# 210                      9.1                      8.2                  1.5
#
#      Nipple Size Top (")  Nipple Size Bottom (")  \
# 210                  2.0                     2.0
#
#      Pipe Centre Top To Floor (mm)  Pipe Centre Bottom To Floor (mm)  \
# 210                          943.0                               102
#
# ...

# %% [markdown]
# Observable difference: "mid section depth" threshold difference

# %%
display(df[df["Products ID"] == 12704][cols])
display(df[df["Products ID"] == 12719][cols])
# Out:
#      Products ID                               Name Castrads SKU  \
# 233        12704  Beeston Hospital Wide 18in - 1957  ORC-B-H-W18
#
#                Family Manufacturer                                     Tags  \
# 233  Beeston Hospital      Beeston  Beeston, Hospital, School, Wide, Window
#
#      Section Length (mm)  Leg Section Depth (mm)  Mid Section Depth (mm)  \
# 233                   64                     178                     178
#
#      Leg Section Height (mm)  Mid Section Height (mm)  \
# 233                      457                      394
#
#      Leg Section Weight (kg)  Mid Section Weight (kg)  Internal Volume (L)  \
# 233                      8.0                      7.2                 0.97
#
#      Nipple Size Top (")  Nipple Size Bottom (")  \
# 233                  1.5                     1.5
#
#      Pipe Centre Top To Floor (mm)  Pipe Centre Bottom To Floor (mm)  \
# 233                          424.0                               102
#
# ...

# %% [markdown]
# Observable difference: "leg section depth" threshold difference

# %%
display(df[df["Products ID"] == 10619][cols])
display(df[df["Products ID"] == 1006][cols])
# Out:
#      Products ID                                   Name Castrads SKU  \
# 276        10619  Beeston Princess Scroll 1 Column 36in   ORC-B-PS36
#
#            Family Manufacturer                                           Tags  \
# 276  Royal School      Beeston  Princess, School, Ideal Plain, School, Scroll
#
#      Section Length (mm)  Leg Section Depth (mm)  Mid Section Depth (mm)  \
# 276                   76                     143                     121
#
#      Leg Section Height (mm)  Mid Section Height (mm)  \
# 276                      914                      864
#
#      Leg Section Weight (kg)  Mid Section Weight (kg)  Internal Volume (L)  \
# 276                      8.6                      7.7                  1.4
#
#      Nipple Size Top (")  Nipple Size Bottom (")  \
# 276                  2.0                     2.0
#
#      Pipe Centre Top To Floor (mm)  Pipe Centre Bottom To Floor (mm)  \
# 276                          870.0                               102
#
# ...

# %% [markdown]
# Observable difference: different family (princess vs royal school)

# %%
display(df[df["Products ID"] == 10649][cols])
display(df[df["Products ID"] == 1036][cols])
# Out:
#      Products ID                                   Name  Castrads SKU  \
# 286        10649  Beeston Princess Scroll 3 Column 36in  ORC-B-PS3C36
#
#            Family Manufacturer  \
# 286  Royal School      Beeston
#
#                                                         Tags  \
# 286  Princess, School, Ideal Plain, School, 3 Column, Scroll
#
#      Section Length (mm)  Leg Section Depth (mm)  Mid Section Depth (mm)  \
# 286                   76                     254                     229
#
#      Leg Section Height (mm)  Mid Section Height (mm)  \
# 286                      914                      864
#
#      Leg Section Weight (kg)  Mid Section Weight (kg)  Internal Volume (L)  \
# 286                     15.3                    13.77                  3.6
#
#      Nipple Size Top (")  Nipple Size Bottom (")  \
# 286                  2.0                     2.0
#
#      Pipe Centre Top To Floor (mm)  Pipe Centre Bottom To Floor (mm)  \
# ...

# %% [markdown]
# Observable difference: different family (princess vs royal school)
